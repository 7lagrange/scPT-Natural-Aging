# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
from datetime import date
import numpy as np
import datetime
from datetime import datetime
import matplotlib.patches as mpatches
pd.options.display.max_rows = 999
pd.options.display.max_columns = 999

# %%
tissues = ["kidney", "liver",  "lung", "heart", 
           "brainFC", "brainHip", "brainCB",
           "BAT", "testis",
            "muscle", "colon", "spleen"] 

len(tissues)
# Out:
# 12

# %%
histone_mark = "H3K9me3"
df_dge_list = []
for tissue in tissues:
    path = f"~/projects/paired_seq_tag/results/{tissue}-merged/dna-qc/{histone_mark}_peak_edgeR_27M_over_3M.csv"
    df_tmp = pd.read_csv(path)
    df_tmp["tissue"] = tissue  # 添加 tissue 信息列
    df_tmp["histone_mark"] = histone_mark  # 添加组蛋白修饰类型
    df_tmp["tissue_ct"] = tissue + '-' + df_tmp["cell_type"]
    df_dge_list.append(df_tmp[['histone_mark', 'gene', 'logFC', 'logCPM', 'LR', 'PValue', 'FDR','cell_type', 'p_val', 'p_val_adj', 'avg_logFC', 'tissue', 'tissue_ct']])
df_dge = pd.concat(df_dge_list, ignore_index=True)
df_dge.shape
# Out:
# (3202420, 13)

# %%
#df_dge[["tissue", "tissue_ct", "gene"]].to_csv("data/peaks.csv")
df_dge[["tissue", "tissue_ct"]].value_counts()
# Out:
# tissue    tissue_ct
# colon     colon-Colonic_epithelial_cell              24286
#           colon-Goblet_cell                          24280
#           colon-Myeloid_cell                         22638
# brainCB   brainCB-GC_ExN                             22616
#           brainCB-Ogc_Glia                           22609
#           brainCB-MLI1_InN                           22598
#           brainCB-Asc_Glia                           22587
#           brainCB-PLI_InN                            22562
#           brainCB-BG_Glia                            22505
# colon     colon-B_cell                               22504
# brainCB   brainCB-MLI2_InN                           22485
# colon     colon-Plasma_cell                          22309
# brainCB   brainCB-Mgc_Glia                           21522
#           brainCB-PC_InN                             21138
# colon     colon-Mural_cell                           21135
# liver     liver-Hepatocytes                          20850
#           liver-Hepatic_stellate_cells               20815
#           liver-Kupffer_cells                        20803
#           liver-endo                                 20803
#           liver-Bcell                                20542
# brainCB   brainCB-Golgi_InN                          20384
#           brainCB-Opc_Glia                           20296
# BAT       BAT-Brown_adipocyte                        20270
#           BAT-Adipocyte                              20268
#           BAT-Vascular_endothelial_cell              20230
#           BAT-Skeletal_muscle_cell                   20222
# colon     colon-T_cell                               20169
# BAT       BAT-ASPC                                   20160
#           BAT-Myeloid_cell                           20147
# liver     liver-Tcell                                20125
# brainFC   brainFC-Doublet                            20063
#           brainFC-InN_Sst_Chodl_InN                  20062
#           brainFC-L4_IT_ExN                          20062
#           brainFC-L6_CT_ExN                          20062
#           brainFC-L2_IT_ENTl_ExN                     20061
#           brainFC-InN_striatum                       20060
#           brainFC-L23_IT_ExN                         20060
#           brainFC-InN_Meis2_InN                      20059
#           brainFC-InN_Sst_InN                        20057
#           brainFC-InN_Pvalb_InN                      20056
#           brainFC-L5_IT_ExN                          20055
#           brainFC-L5_ET_ExN                          20054
#           brainFC-Asc_Glia                           20052
#           brainFC-L6_IT_ExN                          20052
#           brainFC-Ogc_Glia                           20050
#           brainFC-InN_Vip_InN                        20043
#           brainFC-L56_NP_ExN                         20026
#           brainFC-Opc_Glia                           19979
#           brainFC-Mgc_Glia                           19929
# colon     colon-Fibroblast                           19924
# brainFC   brainFC-InN_Lamp5_InN                      19875
#           brainFC-L6b_ExN                            19844
#           brainFC-ExN_Car3                           19725
# brainHip  brainHip-DG_ExN                            19456
#           brainHip-Doublet                           19456
#           brainHip-CA1_ExN                           19453
#           brainHip-CA3_ExN                           19447
#           brainHip-L23_IT_PPP_ExN                    19443
#           brainHip-InN_Pvalb_InN                     19424
#           brainHip-Asc_Glia                          19414
#           brainHip-CT_SUB_ExN                        19406
#           brainHip-SUB_ProS_ExN                      19403
#           brainHip-InN_Sst_InN                       19397
#           brainHip-InN_Vip_InN                       19389
#           brainHip-L2_IT_ENTm_ExN                    19338
#           brainHip-NP_SUB_ExN                        19310
#           brainHip-InN_Lamp5_InN                     19244
#           brainHip-Opc_Glia                          19242
#           brainHip-L23_IT_ENTl_ExN                   19239
# brainCB   brainCB-Doublet                            19206
#           brainCB-UBC_ExN                            19100
# brainHip  brainHip-Ogc_Glia                          18767
# brainFC   brainFC-Endo_Other                         18715
# colon     colon-Enteric_neuron                       18670
# brainHip  brainHip-L3_IT_ENT_ExN                     18642
# heart     heart-Coronary_Arterial_endo               18567
#           heart-Cardiomyocyte                        18565
#           heart-Fibroblast                           18556
#           heart-Macrophage                           18555
#           heart-Endocardial_endo                     18483
# brainCB   brainCB-Fibroblasts_Other                  18433
# kidney    kidney-PT_S1                               18368
#           kidney-PT_S2                               18366
#           kidney-PT_S3                               18365
#           kidney-Vascular_endothelial_cell           18351
#           kidney-LOH_AL                              18346
#           kidney-DCT                                 18326
#           kidney-Fibroblast                          18323
#           kidney-Myeloid_cell                        18261
# BAT       BAT-B_cell                                 18260
# heart     heart-Mural                                18178
# colon     colon-Enteroendocrine_cell                 18083
# BAT       BAT-T_cell                                 18048
# heart     heart-T_cells                              17927
# brainCB   brainCB-Endo_Other                         17920
# heart     heart-Epicardial                           17825
#           heart-B_cells                              17772
# brainHip  brainHip-CA2_ExN                           17731
# heart     heart-neutrophil                           17720
# colon     colon-Tuft_cell                            17022
# heart     heart-Lymphatic_endo                       16736
# BAT       BAT-Mural_cell                             16730
# brainFC   brainFC-Fibroblasts_Other                  16587
# muscle    muscle-Fibro_adipogenic_progenitors        16530
#           muscle-Myonuclei                           16530
#           muscle-Myotendinous_junction_myonuclei     16515
#           muscle-Myeloid_cell                        16506
#           muscle-Vascular_endothelial_cell           16493
#           muscle-Muscle_satellite_cell               16472
# kidney    kidney-B_cell                              16466
# muscle    muscle-Adipocyte                           16435
# lung      lung-Type2_pneumocytes                     16364
#           lung-capillary_endo                        16352
#           lung-Club_cells                            16349
#           lung-Ciliated_cells                        16348
#           lung-interstitial_macrophage               16329
#           lung-Lipofibroblast                        16274
#           lung-Type1_pneumocytes                     16265
#           lung-T_cells                               16148
#           lung-Mesothelial_cells                     16119
# kidney    kidney-T_cell                              16113
# lung      lung-B_cells                               16050
# muscle    muscle-Mural_cells                         16029
# lung      lung-Arterial_endo                         15921
# muscle    muscle-Tenocyte                            15912
# kidney    kidney-Ncam1_positive_cell                 15676
#           kidney-Urothelium                          15671
# liver     liver-Cholangiocytes                       15638
# brainHip  brainHip-Mgc_Glia                          15537
# lung      lung-Eosinophils                           15486
# brainCB   brainCB-Ependymal_Other                    15477
# brainHip  brainHip-Ependymal_Other                   15427
# muscle    muscle-B_cell                              15232
# lung      lung-Alveolar_macrophage                   14977
# muscle    muscle-Neuromuscular_junction_myonuclei    14935
# BAT       BAT-MSC                                    14477
# spleen    spleen-B_cell                              14216
#           spleen-T_cell                              14202
# brainHip  brainHip-NF_Ogc_Glia                       14172
# liver     liver-Mesothelial                          14108
# spleen    spleen-Erythroblast                        14055
# muscle    muscle-Lymphatic_endothelial_cell          13920
# colon     colon-Vascular_endothelial_cell            13906
# kidney    kidney-CD_PC                               13846
# brainFC   brainFC-Choroid_Other                      13738
# testis    testis-SPC                                 13648
#           testis-SPG                                 13645
#           testis-Sertoli                             13640
#           testis-doublet                             13639
#           testis-earlyRS                             13633
#           testis-Leydig                              13599
#           testis-ES                                  13487
# lung      lung-Aerocytes                             13437
# testis    testis-lateRS                              13226
# brainHip  brainHip-Fibroblasts_Other                 13114
#           brainHip-Endo_Other                        13045
# spleen    spleen-Plasma_cell                         12858
#           spleen-Dendritic_cell                      12766
# colon     colon-Lymphatic_endothelial_cell           12751
# brainCB   brainCB-SMC_Other                          12676
#           brainCB-Choroid_Other                      12617
# spleen    spleen-Macrophage                          12611
# testis    testis-Telocyte                            12569
# muscle    muscle-T_cell                              12504
# kidney    kidney-Podocyte                            12416
# spleen    spleen-Neutrophil                          12268
# testis    testis-Macrophage                          12240
# kidney    kidney-CD_IC                               12021
# muscle    muscle-Erythroblast                        11943
# colon     colon-Mesothelial_cell                     11943
# kidney    kidney-Adipocyte                           11597
#           kidney-LOH_DL                              11467
# testis    testis-Myoid                               11444
# lung      lung-lymphatic_endo                        11231
#           lung-mural_cell                            11145
# brainHip  brainHip-CR_InN                            10417
# colon     colon-Ngf_positive_cell                    10232
# brainHip  brainHip-InN_Sst_Chodl_InN                 10134
# brainCB   brainCB-Peri_Other                         10034
# muscle    muscle-Schwann_cell                        10024
# spleen    spleen-Monocyte                             9907
# kidney    kidney-Juxtaglomerular_cell                 9271
# BAT       BAT-Non_MSC                                 8931
# muscle    muscle-Asic2_positive_cell                  8257
# testis    testis-Endo                                 8185
# colon     colon-Enteric_glia                          7538
#           colon-Adipocyte                             6518
# spleen    spleen-Vascular_endothelial_cell            6283
# colon     colon-Mfge8_positive_cell                   5350
# spleen    spleen-Mfge8_positive_cell                  4874
#           spleen-Fibroblast                           4729
# brainHip  brainHip-Peri_Other                         4326
#           brainHip-Choroid_Other                      3381
# Name: count, dtype: int64

# %%
logfc_cutoff = np.log2(1.1)

df_dge_count = (
    df_dge
    .assign(
        up_pval = (df_dge["PValue"] < 0.05) & (df_dge["avg_logFC"] > logfc_cutoff),
        down_pval = (df_dge["PValue"] < 0.05) & (df_dge["avg_logFC"] < -logfc_cutoff),
        up_fdr = (df_dge["FDR"] < 0.05) & (df_dge["avg_logFC"] > logfc_cutoff),
        down_fdr = (df_dge["FDR"] < 0.05) & (df_dge["avg_logFC"] < -logfc_cutoff),
    )
    .groupby(["tissue_ct", "histone_mark"])
    .agg(
        total=("PValue", "size"),
        up_pval=("up_pval", "sum"),
        down_pval=("down_pval", "sum"),
        up_fdr=("up_fdr", "sum"),
        down_fdr=("down_fdr", "sum"),
    )
    .reset_index()
)
df_dge_count["total_pval"] = df_dge_count["up_pval"] + df_dge_count["down_pval"]
df_dge_count.shape
# Out:
# (193, 8)

# %%
df_dge_count.head()
# Out:
#              tissue_ct histone_mark  total  up_pval  down_pval  up_fdr  \
# 0             BAT-ASPC      H3K9me3  20160      789       1052      43
# 1        BAT-Adipocyte      H3K9me3  20268     1193       1393     126
# 2           BAT-B_cell      H3K9me3  18260      560        571       2
# 3  BAT-Brown_adipocyte      H3K9me3  20270     2319       3233    1073
# 4              BAT-MSC      H3K9me3  14477      821        429       0
#
#    down_fdr  total_pval
# 0       194        1841
# 1       168        2586
# 2         2        1131
# 3      2165        5552
# 4         0        1250

# %%
df_dge_count[df_dge_count.tissue_ct.str.contains("Fibroblast")]
# Out:
#                       tissue_ct histone_mark  total  up_pval  down_pval  \
# 17    brainCB-Fibroblasts_Other      H3K9me3  18433      912        408
# 35    brainFC-Fibroblasts_Other      H3K9me3  16587      521        683
# 66   brainHip-Fibroblasts_Other      H3K9me3  13114      190       1256
# 89             colon-Fibroblast      H3K9me3  19924     1419         50
# 106            heart-Fibroblast      H3K9me3  18556     1119       1433
# 117           kidney-Fibroblast      H3K9me3  18323      837        792
# 173           spleen-Fibroblast      H3K9me3   4729      761         42
#
#      up_fdr  down_fdr  total_pval
# 17        0         0        1320
# 35        0         7        1204
# 66        0         1        1446
# 89        0         0        1469
# 106     157       436        2552
# 117      10        28        1629
# 173       0         0         803

# %%
UP_COLOR   = "#E8735A"   # warm red  — up
DOWN_COLOR = "#5B8DB8"   # steel blue — down

sns.set_theme(style="ticks", font_scale=1.0)

# ── Load data ─────────────────────────────────────────────────────────────────
df = df_dge_count
df["tissue"]    = df["tissue_ct"].str.split("-").str[0]
df["cell_type"] = df["tissue_ct"].str.split("-", n=1).str[1]

tissue_order = sorted(df["tissue"].unique())

# ── Core plot function ────────────────────────────────────────────────────────
def plot_diff_bins(up_col, down_col, sort_col, xlabel, title, filename):
    """
    2×6 horizontal grouped bar plot.
    Each tissue = one panel; each cell type = two offset bars (up / down).

    Parameters
    ----------
    up_col   : column name for up counts   (e.g. 'up_pval' or 'up_fdr')
    down_col : column name for down counts (e.g. 'down_pval' or 'down_fdr')
    sort_col : column used to sort cell types within each panel
    xlabel   : x-axis label
    title    : figure suptitle
    filename : output filename (without extension)
    """
    bar_h, gap = 0.35, 0.05
    n_cols, n_rows = 6, 2

    fig, axes = plt.subplots(n_rows, n_cols, figsize=(4.8 * n_cols, 6.5 * n_rows))

    for idx, tissue in enumerate(tissue_order):
        ax = axes.flat[idx]
        sub = df[df["tissue"] == tissue].copy().sort_values(sort_col, ascending=True)
        n_ct = len(sub)

        y    = np.arange(n_ct)
        y_up = y + gap / 2 + bar_h / 2   # up bar: above centre
        y_dn = y - gap / 2 - bar_h / 2   # down bar: below centre

        ax.barh(y_up, sub[up_col],   height=bar_h, color=UP_COLOR,   edgecolor="white", linewidth=0.3)
        ax.barh(y_dn, sub[down_col], height=bar_h, color=DOWN_COLOR, edgecolor="white", linewidth=0.3)

        # Value labels on every bar
        max_val = max(sub[[up_col, down_col]].max().max(), 1)
        for i, (u, d) in enumerate(zip(sub[up_col], sub[down_col])):
            ax.text(u + max_val * 0.015, y_up[i], str(int(u)), va="center", ha="left", fontsize=7)
            ax.text(d + max_val * 0.015, y_dn[i], str(int(d)), va="center", ha="left", fontsize=7)

        ax.set_yticks(y)
        ax.set_yticklabels(sub["cell_type"].tolist(), fontsize=9)
        ax.set_ylim(-0.7, n_ct - 0.3)
        ax.set_title(tissue, fontsize=13, fontweight="bold", pad=5)
        ax.spines[["top", "right"]].set_visible(False)
        ax.tick_params(axis="x", labelsize=9)
        ax.set_xlim(0, max_val * 1.25)

    for col in range(n_cols):
        axes[1, col].set_xlabel(xlabel, fontsize=11)
    for idx in range(len(tissue_order), n_cols * n_rows):
        axes.flat[idx].set_visible(False)

    legend_handles = [
        mpatches.Patch(color=UP_COLOR,   label=up_col),
        mpatches.Patch(color=DOWN_COLOR, label=down_col),
    ]
    fig.legend(handles=legend_handles,
               loc="lower center", bbox_to_anchor=(0.5, -0.02),
               ncol=2, fontsize=12, frameon=False)

    fig.suptitle(title, fontsize=16, fontweight="bold", y=1.01)
    plt.tight_layout(h_pad=4, w_pad=3)


# ── Generate plots ────────────────────────────────────────────────────────────

# p-value threshold
plot_diff_bins(
    up_col   = "up_pval",
    down_col = "down_pval",
    sort_col = "total_pval",
    xlabel   = "Number of diff peaks (p-val)",
    title    = "Differential peaks per cell type (H3K9me3, p-val threshold)",
    filename = "diff_bins_pval_per_tissue",
)

# FDR threshold
df["total_fdr"] = df["up_fdr"] + df["down_fdr"]
plot_diff_bins(
    up_col   = "up_fdr",
    down_col = "down_fdr",
    sort_col = "total_fdr",
    xlabel   = "Number of diff peaks (FDR)",
    title    = "Differential peaks per cell type (H3K9me3, FDR threshold)",
    filename = "diff_bins_fdr_per_tissue",
)
